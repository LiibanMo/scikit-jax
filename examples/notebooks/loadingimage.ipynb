# %%
import matplotlib.pyplot as plt
import numpy as np
import jax.numpy as jnp

import matplotlib.image as mpimg
img = mpimg.imread('/Users/liibanmohamud/Desktop/scikit-jax/assets/logo.png')
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (200, 200, 4)

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open('/Users/liibanmohamud/Desktop/scikit-jax/assets/logo.png')
new_size = (800, 400)  # Width and height in pixels
img_resized = img.resize(new_size)
plt.imshow(img_resized)


jnp.array(img_resized).shape
# Out:
# (400, 800, 4)

# %%
plt.imsave(fname='/Users/liibanmohamud/Desktop/scikit-jax/assets/logo_resized.png', arr=jnp.array(img_resized))
